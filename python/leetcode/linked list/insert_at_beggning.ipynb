# %%
class Node:
    def __init__(self,data):
        self.node = data
        self.next = None
a = Node(5)
b = Node(6)
c = Node(7)
a.next = b
b.next = c

def trav(curr):
    curr=head
    while curr!=None:
        print(curr.node,end=" ")
        curr=curr.next
head = a
trav(head)
# Out:
# 5 6 7

# %%
# inset at biggning
newNode = Node(4)
newNode.next = head
head = newNode
trav(head)
# Out:
# 4 5 6 7

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 3
#       1 end_node = Node(8)
#       2 cnode = head
# ----> 3 while cnode.next!=None:
#       4     cnode=end_node.next
#       5 cnode = cnode.next
#
# AttributeError: 'NoneType' object has no attribute 'next'
